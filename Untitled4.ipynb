# %% [markdown]
# **Power BI Visuals**

# %% [markdown]
# 1  . Total sales = SUM('Table'[sales])
#
# 2  . Sales by ship mode = SUM (values('table'[ship mode]),CALCUTALE (SUM
#      ('Table'[sales])))
#
# 3  . Monthyear = FORMATE ([Date],"MMM YYYY")
#
# 4  . Sales by category = SUM(VALUES('Table'[category]),SUM(;Table'[sales]))
#
# 5  . Max sales month = MAX (ALL('Table'[monthyear]),
#      CALCULATE(SUM('Table'[sales])))
#
# 6  . sales Breakdown = SUM ('Table'[sales])
#
# 7  . Negative profit = CALCULATE(SUM('Table'[profit]),'Table'[Discount]>0.3
#      &&''Table'[profit] < 0 )
#
# 8  . Order count = DISTINCTCOUNT('Table'[Order ID])
#
#
# 9  . Profit waterfall = CALCULATE(SUM('Table'[profit]),ALLEXPECT('Table'
#      [country],'Table'[category]))
#
# 10  . Total sales = SUM('Table'[sales])
#       Total profit = SUM('Table'[profit])
